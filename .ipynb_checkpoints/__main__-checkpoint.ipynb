# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
dataSet = pd.read_excel('Concrete_Data.xls')

# %%
dataSet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
# Cement (component 1)(kg in a m^3 mixture)                1030 non-null float64
# Blast Furnace Slag (component 2)(kg in a m^3 mixture)    1030 non-null float64
# Fly Ash (component 3)(kg in a m^3 mixture)               1030 non-null float64
# Water  (component 4)(kg in a m^3 mixture)                1030 non-null float64
# Superplasticizer (component 5)(kg in a m^3 mixture)      1030 non-null float64
# Coarse Aggregate  (component 6)(kg in a m^3 mixture)     1030 non-null float64
# Fine Aggregate (component 7)(kg in a m^3 mixture)        1030 non-null float64
# Age (day)                                                1030 non-null int64
# Concrete compressive strength(MPa, megapascals)          1030 non-null float64
# dtypes: float64(8), int64(1)
# memory usage: 72.5 KB

# %%
dataSet.isnull().sum()
# Out:
# Cement (component 1)(kg in a m^3 mixture)                0
# Blast Furnace Slag (component 2)(kg in a m^3 mixture)    0
# Fly Ash (component 3)(kg in a m^3 mixture)               0
# Water  (component 4)(kg in a m^3 mixture)                0
# Superplasticizer (component 5)(kg in a m^3 mixture)      0
# Coarse Aggregate  (component 6)(kg in a m^3 mixture)     0
# Fine Aggregate (component 7)(kg in a m^3 mixture)        0
# Age (day)                                                0
# Concrete compressive strength(MPa, megapascals)          0
# dtype: int64

# %%
dataSet.describe()
# Out:
#        Cement (component 1)(kg in a m^3 mixture)  \
# count                                1030.000000
# mean                                  281.165631
# std                                   104.507142
# min                                   102.000000
# 25%                                   192.375000
# 50%                                   272.900000
# 75%                                   350.000000
# max                                   540.000000
#
#        Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# count                                        1030.000000
# mean                                           73.895485
# std                                            86.279104
# min                                             0.000000
# 25%                                             0.000000
# 50%                                            22.000000
# 75%                                           142.950000
# max                                           359.400000
#
#        Fly Ash (component 3)(kg in a m^3 mixture)  \
# count                                 1030.000000
# mean                                    54.187136
# std                                     63.996469
# min                                      0.000000
# 25%                                      0.000000
# 50%                                      0.000000
# 75%                                    118.270000
# max                                    200.100000
#
#        Water  (component 4)(kg in a m^3 mixture)  \
# count                                1030.000000
# mean                                  181.566359
# std                                    21.355567
# min                                   121.750000
# 25%                                   164.900000
# 50%                                   185.000000
# 75%                                   192.000000
# max                                   247.000000
#
#        Superplasticizer (component 5)(kg in a m^3 mixture)  \
# count                                        1030.000000
# mean                                            6.203112
# std                                             5.973492
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             6.350000
# 75%                                            10.160000
# max                                            32.200000
#
#        Coarse Aggregate  (component 6)(kg in a m^3 mixture)  \
# count                                        1030.000000
# mean                                          972.918592
# std                                            77.753818
# min                                           801.000000
# 25%                                           932.000000
# 50%                                           968.000000
# 75%                                          1029.400000
# max                                          1145.000000
#
#        Fine Aggregate (component 7)(kg in a m^3 mixture)    Age (day)  \
# count                                        1030.000000  1030.000000
# mean                                          773.578883    45.662136
# std                                            80.175427    63.169912
# min                                           594.000000     1.000000
# 25%                                           730.950000     7.000000
# 50%                                           779.510000    28.000000
# 75%                                           824.000000    56.000000
# max                                           992.600000   365.000000
#
#        Concrete compressive strength(MPa, megapascals)
# count                                       1030.000000
# mean                                          35.817836
# std                                           16.705679
# min                                            2.331808
# 25%                                           23.707115
# 50%                                           34.442774
# 75%                                           46.136287
# max                                           82.599225

# %%
dataSet.columns = ['Cement','Slag','Ash','Water','Superplasticizer','Coarse','Fine','Age','strength']

# %%
dataSet.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002263865D7B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022638998A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000226389CA048>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000226389EF550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022638A15AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022638A2D908>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022638640E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000226385FD470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000226385FD4A8>]],
#       dtype=object)

# %%
X = dataSet.iloc[:,:-1].values
y= dataSet.iloc[:,-1].values
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(X,y,test_size=0.30, random_state=1)

# %%
from sklearn.preprocessing import MinMaxScaler
std = MinMaxScaler()
X_train = std.fit_transform(X_train)
X_test = std.transform(X_test)

# %%
print('The Features to be trained on :', X_train.shape )
print('The Labels to be trained on :', y_train.shape )
print('The Features to be tested on :', X_test.shape )
print('The Labels to be tested on :', y_test.shape )
print('X_train type : ', type(X_train), 'X_test type :',type(X_test) ,'y_train type :', type(y_train) , 'y_test type :', type(y_test) )
# Out:
# The Features to be trained on : (721, 8)
# The Labels to be trained on : (721,)
# The Features to be tested on : (309, 8)
# The Labels to be tested on : (309,)
# X_train type :  <class 'numpy.ndarray'> X_test type : <class 'numpy.ndarray'> y_train type : <class 'numpy.ndarray'> y_test type : <class 'numpy.ndarray'>

# %%
# from sklearn.preprocessing import PolynomialFeatures
# poly =PolynomialFeatures(degree=3)
# X_train = poly.fit_transform(X_train)
# X_test = poly.transform(X_test)
# X_train

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import r2_score
conf = r2_score(y_pred,y_test)
conf
# Out:
# 0.37471312838277326

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
plt.title('PREDICTION VS ACTUAL ', fontsize=24 , fontstyle='italic')


plt.plot(range(len(y_test)), y_test, '.')
plt.plot(range(len(y_test)),y_pred,c='r')
plt.show()

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score,confusion_matrix,mean_squared_error
def rmse(y_test,y_pred):
      return np.sqrt(mean_squared_error(y_test,y_pred))

print("rmse : ", rmse(y_test, y_pred))
# Out:
# rmse :  10.963255077364177

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=3)
X_train = poly.fit_transform(X_train)
X_test = poly.transform(X_test)

# %%
print('The Features to be trained on :', X_train.shape )
print('The Labels to be trained on :', y_train.shape )
print('The Features to be tested on :', X_test.shape )
print('The Labels to be tested on :', y_test.shape )
print('X_train type : ', type(X_train), 'X_test type :',type(X_test) ,'y_train type :', type(y_train) , 'y_test type :', type(y_test) )
# Out:
# The Features to be trained on : (721, 165)
# The Labels to be trained on : (721,)
# The Features to be tested on : (309, 165)
# The Labels to be tested on : (309,)
# X_train type :  <class 'numpy.ndarray'> X_test type : <class 'numpy.ndarray'> y_train type : <class 'numpy.ndarray'> y_test type : <class 'numpy.ndarray'>

# %%
pd.DataFrame(X_train).head()
# Out:
#    0         1         2         3         4         5         6         7    \
# 0  1.0  0.274795  0.000000  0.483108  0.539242  0.138509  0.498290  0.693226
# 1  1.0  0.181233  0.000000  0.834633  0.381956  0.234783  0.763876  0.461114
# 2  1.0  0.541096  0.000000  0.000000  0.600798  0.000000  0.501050  0.469142
# 3  1.0  0.251142  0.393155  0.000000  0.652695  0.000000  0.517252  0.391370
# 4  1.0  0.785388  0.066778  0.394803  0.321357  0.319876  0.498050  0.296036
#
#         8         9        ...            155       156       157       158  \
# 0  0.035714  0.075512      ...       0.123722  0.172123  0.008868  0.239460
# 1  0.074176  0.032845      ...       0.445727  0.269063  0.043282  0.162420
# 2  0.035714  0.292785      ...       0.125789  0.117779  0.008966  0.110278
# 3  0.005495  0.063072      ...       0.138390  0.104711  0.001470  0.079228
# 4  0.074176  0.616835      ...       0.123543  0.073433  0.018400  0.043648
#
#         159       160       161       162       163           164
# 0  0.012337  0.000636  0.333139  0.017163  0.000884  4.555394e-05
# 1  0.026127  0.004203  0.098045  0.015772  0.002537  4.081193e-04
# 2  0.008395  0.000639  0.103255  0.007861  0.000598  4.555394e-05
# 3  0.001112  0.000016  0.059946  0.000842  0.000012  1.658769e-07
# 4  0.010937  0.002740  0.025944  0.006501  0.001629  4.081193e-04
#
# [5 rows x 165 columns]

# %%
from sklearn.linear_model import Lasso
lasso = Lasso(alpha = .09, normalize=True)
lasso.fit(X_train,y_train)
plt.plot(y_train, '.',lasso.predict(X_train),'-o')
y_pred = lasso.predict(X_test)
plt.show()
print("rmse : ", rmse(y_test, y_pred))
# Out:
# rmse :  10.401964844051031

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)

# %%
print("rmse : ", rmse(y_test, y_pred))
# Out:
# rmse :  7.097622693961516

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
plt.title('PREDICTION VS ACTUAL ', fontsize=24 , fontstyle='italic')


plt.plot(range(len(y_test)), y_test, '.')
plt.plot(range(len(y_test)),y_pred,c='r')
plt.show()
